# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.ceneo.pl/47293506#tab=reviews"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
headers = {
"Cookie": "sv3=1.0_4e90e473-1e16-11f1-a051-07ce2438207e; urdsc=1; userCeneo=ID=6862a48a-8e79-42f8-9d2e-e20574cf0567; __RequestVerificationToken=BfyUJKkqqDAljfmkeop7nLjgYNLtt7dYGMxOCKljrY3rDMVEg0JqHd5BrWNOYIU-K5neU3mm8nZ2kxGM5OTijTufO2SRfU5hHloCC7pD2gg1; ai_user=t6oo/|2026-03-12T13:20:59.221Z; __utmf=d94d560269505dc9f83e605956752c9a_qO356z2L9VCzLolxyxY7Gg%3D%3D; ai_session=z4fjs|1773321659503|1773321659503; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; browserBlStatus=0; ga4_ga=GA1.2.4e90e473-1e16-11f1-a051-07ce2438207e; _gcl_au=1.1.20006543.1773321663; consentcookie=...; FPID=FPID2.2.N7eDTR305P4nvZXjNY5dkXGEYHamC3kYL0MZgHsIdc0%3D; FPLC=D9IG%2BJgWx7yecM7AR5IrUjcA4bNJgwOoveMZKwPZF8z506%2BPrkdl6I2eFcI7kk7anaHfB%2BuYha2KT1MKYnU%2By7H3q1XStmJMnB5Gl%2FIKihIjoCo%3D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T13%3A21%3A03.143Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%224e90e473-1e16-11f1-a051-07ce2438207e%22%2C%22expiryDate%22%3A%222027-03-12T13%3A21%3A03.143Z%22%7D; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%228VFDrGssox65mbFdKKkG%22%2C%22expiryDate%22%3A%222027-03-12T13%3A21%3A03.144Z%22%7D; _tt_enable_cookie=1; _ttp=01KKH3AD2BAYWGCG2PY0AA1Z2W_.tt.1; ttcsid=1773321663565::WLHMwQVdV_F20TWX8Ps-.1.1773321673582.0; ttcsid_CNK74OBC77U1PP7E4UR0=1773321663565::r9CtNmkN-JQpYvOFiBL1.1.1773321673586.1; ga4_ga_K2N2M0CBQ6=GS2.2.s1773321659$o1$g0$t1773321694$j28$l0$h1072525426",
"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
"host" : "www.ceneo.pl"
}

# %% [markdown]
# ### Parsowanie strony z opiniami o produkcie

# %%
page_dom = BeautifulSoup(response.text,"html.parser")

# %%
opinions = page_dom.select("div.js_product-review:not(.user-post--highlight)")
print(len(opinions))
print(type(opinions))
# Out:
# 10
# <class 'bs4.element.ResultSet'>

# %%
opinion = page_dom.select_one("div.js_product-review:not(.user-post--highlight)")
print(type(opinion))
# Out:
# <class 'bs4.element.Tag'>

# %%
opinion = opinions.pop(0)
print(type(opinion))
print(opinion)
# Out:
# <class 'bs4.element.Tag'>
# <div class="user-post user-post__card js_product-review" data-entry-id="16601645">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar user-rank__avatar" data-bg="/Content/img/account/avatar/0.svg"></div>
# </div>
# <div class="user-post__body">
# <div class="user-post__content">
# <div>
# <span class="user-post__author-name">
# k...r
# </span>
# <span class="user-post__score">
# <span class="screen-reader-text">Ocena:</span>
# <span class="score-container score-container--s js_score-container">
# <span class="score-marker score-marker--s" style="width: 100.0%"></span>
# </span>
# <span class="user-post__score-count">5/5</span>
# <span class="user-post__author-recomendation">
# <em class="recommended">Polecam</em>
# </span>
# </span>
# </div>
# <div class="mb-4">
# <span class="verified-purchase">
# Zaufana Opinia potwierdzona zakupem
# </span>
# <span class="user-post__published">
# <span class="user-post__published">
# Wystawiono
# <time datetime="2022-10-06 11:51:00">4 lata temu, </time>
# <time datetime="2022-09-30 08:22:14">po 6 dniach</time> użytkowania<span>.</span>
# </span>
# </span>
# </div>
# <div class="user-post__text">Myszka jest rewelacyjna. To jakby porównać odgłos klawiatury z czasów WIN95 z współczesną cichutką klawiaturą laptopową. I jedno i drugie będzie działało ale po co słuchać tego irytującego klikania. A pomnóż  to np. x10 osób w biurze:)
# Bardzo udany zakup.</div>
# <div class="review__section-title mt-5">
# Rekomendowane oferty
#  <span class="js_promotions-legend-tooltip recommendations-tooltip js_review-offer-tooltip">
# <span class="context-help"></span>
# <span class="js_review-offer-tooltip-content hidden">Oferty rekomendowane przez Serwis na podstawie kolejności ofert na karcie produktu</span>
# </span>
# </div>
# <div class="review-related-offers">
# <div class="go-to-shop js_offer-container-click js_shop-review-products-row review-product js_recommendations-click-no-offer" data-affiliation="16202" data-algorithm-tag="recommendation_offers" data-brand="Logitech" data-category-id="87" data-categoryid="87" data-city="ProductPage" data-click-target="_blank" data-click-url="/Click/Offer/?e=XHj_X0vJYGtG5U71ADWJSZZOrrhowJD-b27yBU--VoqLFP-3QxeoqQJWu61ijwwODSEYk4wRLkxV2sLHUFUM5cP6SuPL5ez-pFfTGdu8JNYUX7yyuIP7t5aPobEQ1kezbJq6FF1JLvt3RheZTCr1A_L9nIDdUfjXmL08DnTuoQH86uEYpcFKJ0UOIH-Ppq-kw0I7zKNMe9g3LldrKweO7xQ11HQ9od4HRDqhDDgXQpGfChVDIQw7uxKx0hYjJMnlNGRnKWJHYL0Mz9tavzSJt8i_z6nMYa-B1xLYbZf3Fz5WJzY45kN6W2GsYuq-spUv6vT85sHq7sQFdgHjDvGhn-S1L2Nz0x4QYCIOGKI4ABqq4xSuyHgFLqVQTMJZBQ3dpVBMwlkFDd2FgtoYFts3vdWBNxFx-jpPpVBMwlkFDd2lUEzCWQUN3clREr49svqQuUYpLcy7xT3HlmP0cqp8JyTVqVdW5bI9vVj0e2GZfoS5rgnfoMDK96VQTMJZBQ3dPsWq8AdXNus=&amp;ctx=CgsIgvTZlOSNiz8QBRIkMzRjYzEyODAtMzQwOS0xMWYxLWE2NjktMzYxNTBmNTI3YTc4GiQzNGNjNjBlNS0zNDA5LTExZjEtYTVhMC0zNjE1MGY1MjdhNzg=&amp;a=2" data-gacategoryname="/Komputery/Myszy i trackballe" data-gaproductid="DC/S16202/P47293506/" data-gaproductname="47293506/Logitech M330 Silent Plus Czarna (910004909)" data-id="04b28ea6-024b-4c81-afe9-e047225be97a" data-isbidding="0" data-isnonintegrated="False" data-name="Mysz LOGITECH M330 Silent Plus 910-004909 DARMOWY TRANSPORT" data-offer='"217814454"' data-offerid="217814454" data-offerparams="xml1" data-pid="47293506" data-placement-tag="reviews_shop_offers" data-position="1" data-price="129,0500" data-productid="47293506" data-productminprice="56.96" data-productname="Logitech M330 Silent Plus Czarna (910004909)" data-recommendation-position="1" data-shop='"16202"' data-shopurl="electro.pl" data-trackinfotype="Click">
# <div class="review-product__photo">
# <img alt="Electro.pl" src="//image.ceneostatic.pl/imageschain/data/shops/16202/logo.jpg;data/custom_images/585/custom_image.png">
# </img></div>
# <div class="review-product__content">
# <div class="review-product__info">
# Mysz LOGITECH M330 Silent Plus 910-004909 DARMOWY TRANSPORT
# </div>
# <div>
# <span class="price-format nowrap"><span class="price"><span class="value">129</span><span class="penny">,05</span></span>zł</span>
# </div>
# </div>
# <div class="review-product__actions">
# <a class="button button-primary button--small js_shop-review-products-go-to-shop go-to-shop" href="/Click/Offer/?e=XHj_X0vJYGtG5U71ADWJSZZOrrhowJD-b27yBU--VoqLFP-3QxeoqQJWu61ijwwODSEYk4wRLkxV2sLHUFUM5cP6SuPL5ez-pFfTGdu8JNYUX7yyuIP7t5aPobEQ1kezbJq6FF1JLvt3RheZTCr1A_L9nIDdUfjXmL08DnTuoQH86uEYpcFKJ0UOIH-Ppq-kw0I7zKNMe9g3LldrKweO7xQ11HQ9od4HRDqhDDgXQpGfChVDIQw7uxKx0hYjJMnlNGRnKWJHYL0Mz9tavzSJt8i_z6nMYa-B1xLYbZf3Fz5WJzY45kN6W2GsYuq-spUv6vT85sHq7sQFdgHjDvGhn-S1L2Nz0x4QYCIOGKI4ABqq4xSuyHgFLqVQTMJZBQ3dpVBMwlkFDd2FgtoYFts3vdWBNxFx-jpPpVBMwlkFDd2lUEzCWQUN3clREr49svqQuUYpLcy7xT3HlmP0cqp8JyTVqVdW5bI9vVj0e2GZfoS5rgnfoMDK96VQTMJZBQ3dPsWq8AdXNus=&amp;ctx=CgsIgvTZlOSNiz8QBRIkMzRjYzEyODAtMzQwOS0xMWYxLWE2NjktMzYxNTBmNTI3YTc4GiQzNGNjNjBlNS0zNDA5LTExZjEtYTVhMC0zNjE1MGY1MjdhNzg=&amp;a=2" rel="nofollow noopener" target="_blank">
# Idź do sklepu
# </a>
# </div>
# </div>
# </div>
# <div class="user-post__bottom">
# <span class="user-post__comment link link--accent">
# <a class="user-post__reply mr-0 link link--accent js_toggle-product-review-comments" href="#product-review-comments-16601645" rel="nofollow">Skomentuj opinię</a>
# </span>
# </div>
# </div>
# <div class="user-post__info">
# <div class="d-flex align-items-center justify-content-end">
# <div class="js_product-review-usefulness vote">
# <button class="vote-yes js_product-review-vote js_vote-yes" data-new-icon="vote-up" data-product-id="47293506" data-review-id="16601645" data-total-vote="0" data-url="SetOpinionVote" data-vote="1" data-voted="false"><span id="votes-yes-16601645">0</span></button>
# <button class="vote-no js_product-review-vote js_vote-no" data-new-icon="vote-down" data-product-id="47293506" data-review-id="16601645" data-total-vote="0" data-url="SetOpinionVote" data-vote="0" data-voted="false"><span id="votes-no-16601645">0</span></button>
# </div>
# <div class="dropdown-wrapper">
# <span class="dots-icon-vert" data-toggle="dropdown"></span>
# <ul class="dropdown-menu force-left">
# <li class="dropdown-menu__item" data-product-id="47293506" data-review-id="16601645">
# <div class="js_report-abuse report-abuse cursor-pointer" data-report-type="1" role="button">
# <span>
# Zgłoś </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="review-pz" data-hint="Opinia została napisana przez Użytkownika, który kupił produkt.">
# <em>Transakcja pochodzi z Marketplace Ceneo (usługi Kup Teraz).</em>
# </div>
# </div>
# <div class="user-post__comments js_product-review-comments js_product-review-hook js_product-review-comments-list hidden" id="product-review-comments-16601645">
# <a class="user-post js_product-review-comment-toggle" data-comments-count="0" data-product-review-id="47293506" data-review-id="16601645" href="#product-review-comment-16601645" role="button">
# <div class="user-post__header">
# <div class="js_lazy user-post__avatar" data-bg="/Content/img/account/avatar/0.svg"></div>
# </div>
# <div class="user-post__body">
# <div class="user-post__content">
# <div class="user-post__text mt-0">
# <label for="user-comment-16601645">Twój komentarz</label>
# <textarea class="user-post__textarea user-post__textarea--dummy" id="user-comment-16601645" name="user-comment-16601645" placeholder="Wpisz swój komentarz"></textarea>
# </div>
# </div>
# </div>
# </a>
# <div class="js_product-review-form-hook" id="product-review-comment-16601645"></div>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Analiza struktury pojedynczej opinii

# %% [markdown]
# |składowa|nazwa|selektor|
# |--------|-----|--------|
# |opinia|opinion|div.js_product-review|
# |identyfikator|opinion_id|[data-entry-id]|
# |autor|author|span.user-post__author-name|
# |treść|content|div.user-post__text|
# |ocena|score|span.user-post__score-count|
# |rekomendacje|recommendation|span.user-post__author-recomendation > em|
# |lista zalet|positives|div.review-feature__item--positive|
# |lista wad|negatives|div.review-feature__item--negative|
# |dla ilu przydatna|useful|button.vote-yes > span|
# |dla ilu nieprzydatna|useless|button.vote-no > span|
# |data zamieszczenia|publish_date|span.user-post__published > time:nth-child(1)[datetime]|
# |data zakupu|purchase_date|span.user-post__published > time:nth-child(2)[datetime]|

# %% [markdown]
# dopasowac do kodu podmienic jakies gowienko
